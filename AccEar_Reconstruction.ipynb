# %% [markdown]
# <a href="https://colab.research.google.com/github/SezarTheGreat/AccEar/blob/main/AccEar_Reconstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Extract StealthyIMU dataset to local SSD
# !mkdir -p /content/dataset
# !unzip -q "/content/drive/MyDrive/Copy of StealthyIMU_dataset.zip" -d /content/dataset/

# 2. Copy code files from your Drive bundle to Colab root
# !cp "/content/drive/MyDrive/accear_kaggle_bundle (Unzipped Files)"/*.py /content/ 2>/dev/null || true
# !cp -r "/content/drive/MyDrive/accear_kaggle_bundle (Unzipped Files)"/StealthyIMU_dataset /content/ 2>/dev/null || true

# 3. Verify extracted scripts and dataset
# !ls -la /content/accear_cgan_kaggle.py
# Out:
# -rw------- 1 root root 39857 Aug  2 15:40 /content/accear_cgan_kaggle.py

# %%
# !pip install -q "numpy<2" scipy torchaudio tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 64.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !python /content/accear_cgan_kaggle.py \
    --epochs 200 \
    --batch-size 64 \
    --num-samples 2000 \
    --lr 0.0002 \
    --checkpoint-dir "/content/drive/MyDrive/AccEar_Checkpoints" \
    --dataset-dir /content/dataset
# Out:
# === AccEar cGAN Training Execution ===
# Active Compute Device: cuda
# Available GPUs: 1 x Tesla T4
# [TRAIN] Operating with Speech Commands dataset / IMU sensor dataset simulator.
# Starting Training for Epochs 1 -> 200 (AMP Enabled: True, Batch Size: 64)...
# Epoch [001/200] - D Loss: 0.3624 | G Loss: 18.0406 | Spectrogram L1: 0.1641
#  [BEST MODEL UPDATED] Epoch 001 -> Best Spectrogram L1: 0.1641 Saved: /content/drive/MyDrive/AccEar_Checkpoints/accear_cgan_best_model.pt
#  [BEST MODEL UPDATED] Epoch 002 -> Best Spectrogram L1: 0.1059 Saved: /content/drive/MyDrive/AccEar_Checkpoints/accear_cgan_best_model.pt
#  [BEST MODEL UPDATED] Epoch 003 -> Best Spectrogram L1: 0.1004 Saved: /content/drive/MyDrive/AccEar_Checkpoints/accear_cgan_best_model.pt
#  [BEST MODEL UPDATED] Epoch 004 -> Best Spectrogram L1: 0.0918 Saved: /content/drive/MyDrive/AccEar_Checkpoints/accear_cgan_best_model.pt
# Epoch [005/200] - D Loss: 0.0924 | G Loss: 13.7515 | Spectrogram L1: 0.0837
# ...

# %%
# 1. Run Evaluation on Best Model Checkpoint
# !python /content/accear_cgan_kaggle.py \
    --eval-best \
    --checkpoint-dir "/content/drive/MyDrive/AccEar_Checkpoints" \
    --dataset-dir /content/dataset

# 2. Play Reconstructed Audio Inline
from IPython.display import Audio, display
import os

best_wav = "/content/drive/MyDrive/AccEar_Checkpoints/evaluated_best_reconstruction.wav"
if not os.path.exists(best_wav):
    best_wav = "/content/drive/MyDrive/AccEar_Checkpoints/sample_reconstruction_epoch_200.wav"

if os.path.exists(best_wav):
    print("🔊 Reconstructed Audio Waveform (AccEar cGAN Best Model):")
    display(Audio(best_wav))
# Out:
# === AccEar Model Evaluation ===
# Loading Best Model Checkpoint: /content/drive/MyDrive/AccEar_Checkpoints/accear_cgan_best_model.pt
# [TEST] Operating with Speech Commands dataset / IMU sensor dataset simulator.
# Evaluation Complete!
# Best Epoch: 194
# Best L1 Loss: 0.0403
# Reconstructed Wav Saved: /content/drive/MyDrive/AccEar_Checkpoints/evaluated_best_reconstruction.wav
# 🔊 Reconstructed Audio Waveform (AccEar cGAN Best Model):
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
