# %% [markdown]
# # AccEar: Accelerometer Acoustic Eavesdropping with Unconstrained Vocabulary
# ## Conditional GAN (cGAN) Speech Reconstruction Pipeline
# ### Resume Training & Fast Execution Notebook

# %%
# Step 1: Copy all Python package files to working directory
# !find /kaggle/input/ -name "*.py" -exec cp -v {} . \;
# !ls -la accear_cgan_kaggle.py

# %%
# Step 2: Resume Training from Epoch 44 Checkpoint up to Epoch 200
# Automatically finds the latest accear_cgan_epoch_044.pt or best model checkpoint
# !python accear_cgan_kaggle.py \
    --epochs 200 \
    --batch-size 128 \
    --resume auto \
    --checkpoint-dir /kaggle/working/checkpoints \
    --dataset-dir /kaggle/input/datasets/sezarthegreat/stealthyimu-dataset/StealthyIMU_dataset

# %%
# Step 3: Evaluate Best Saved Checkpoint and generate audio .wav sample
# !python accear_cgan_kaggle.py \
    --eval-best \
    --checkpoint-dir /kaggle/working/checkpoints \
    --dataset-dir /kaggle/input/datasets/sezarthegreat/stealthyimu-dataset/StealthyIMU_dataset
